# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist=input_data.read_data_sets("MNIST_data",one_hot=True)

#每个批次的大小
batch_size=100
#计算一共多少批次
n_batch=mnist.train.num_examples//batch_size
#定义两个placeholder
x=tf.placeholder(tf.float32,[None,784])
y=tf.placeholder(tf.float32,[None,10])
keep_prob=tf.placeholder(tf.float32)


#创建一个简答的神经网络
W1=tf.Variable(tf.truncated_normal([784,200],stddev=0.1))
b1=tf.Variable(tf.zeros([200])+0.1)
L1=tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop=tf.nn.dropout(L1,keep_prob)


W2=tf.Variable(tf.truncated_normal([200,20],stddev=0.1))
b2=tf.Variable(tf.zeros([20])+0.1)
L2=tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop=tf.nn.dropout(L2,keep_prob)

W3=tf.Variable(tf.truncated_normal([20,15],stddev=0.1))
b3=tf.Variable(tf.zeros([15])+0.1)
L3=tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop=tf.nn.dropout(L3,keep_prob)

W4=tf.Variable(tf.truncated_normal([15,10],stddev=0.1))
b4=tf.Variable(tf.zeros([10])+0.1)

prediction=tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)


#定义二次代价函数
# loss=tf.reduce_mean(tf.square(y-prediction))
loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
#使用梯度下降法
train_step=tf.train.GradientDescentOptimizer(0.2).minimize(loss)

init=tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction=tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
     #argmax返回一维张量中最大的值所在的位置 
#准确率
accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(31):
        for batch in range(n_batch):
            batch_xs,batch_ys=mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_prob:0.7})
            
        test_acc=sess.run(accuracy,feed_dict={x:mnist.test.images,
                                         y:mnist.test.labels,
                                        keep_prob:1.0})
        train_acc=sess.run(accuracy,feed_dict={x:mnist.train.images,
                                         y:mnist.train.labels,
                                        keep_prob:1.0})
        print("Iteration "+str(epoch)+", Testing accuracy "+str(test_acc)+",Training Accuracy "+str(train_acc))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iteration 0, Testing accuracy 0.5048,Training Accuracy 0.495455
# Iteration 1, Testing accuracy 0.7772,Training Accuracy 0.767036
# Iteration 2, Testing accuracy 0.8267,Training Accuracy 0.822382
# Iteration 3, Testing accuracy 0.8346,Training Accuracy 0.8302
# Iteration 4, Testing accuracy 0.8426,Training Accuracy 0.836982
# Iteration 5, Testing accuracy 0.8445,Training Accuracy 0.841055
# Iteration 6, Testing accuracy 0.8484,Training Accuracy 0.842345
# Iteration 7, Testing accuracy 0.8488,Training Accuracy 0.843836
# Iteration 8, Testing accuracy 0.8528,Training Accuracy 0.848491
# Iteration 9, Testing accuracy 0.8539,Training Accuracy 0.850782
# Iteration 10, Testing accuracy 0.8544,Training Accuracy 0.851545
# Iteration 11, Testing accuracy 0.8552,Training Accuracy 0.853745
# ...

# %%
# overfitting 
# there is a big difference between testing and training accuracy


# Iteration 29, Testing accuracy 0.9706,Training Accuracy 0.988345
# Iteration 30, Testing accuracy 0.9709,Training Accuracy 0.989236

# using dropout can prevent from overfitting but its gradient descent more slowly 
# Iteration 29, Testing accuracy 0.8684,Training Accuracy 0.8708
# Iteration 30, Testing accuracy 0.8681,Training Accuracy 0.870873
